# %%
import sys
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import palettable

sys.path.append('../../src/write_entities/')
sys.path.append('../../src/util/')

from define_exposures import call_exposures
# Out:
# 2020-02-28 16:50:29,898 - climada - DEBUG - Loading default config file: /Users/zeliestalhanske/anaconda3/climada_python-1.3.1/climada/conf/defaults.conf

# %%
exposures = call_exposures()
# Out:
# 2020-02-28 16:50:41,865 - climada.util.coordinates - INFO - Setting geometry points.
# 2020-02-28 16:50:49,113 - climada.entity.exposures.base - INFO - tag metadata set to default value:  File:
#  Description:
# 2020-02-28 16:50:49,113 - climada.entity.exposures.base - INFO - ref_year metadata set to default value: 2018
# 2020-02-28 16:50:49,114 - climada.entity.exposures.base - INFO - meta metadata set to default value: None
# 2020-02-28 16:50:49,115 - climada.entity.exposures.base - INFO - centr_ not set.
# 2020-02-28 16:50:49,115 - climada.entity.exposures.base - INFO - deductible not set.
# 2020-02-28 16:50:49,116 - climada.entity.exposures.base - INFO - cover not set.
# 2020-02-28 16:50:49,116 - climada.entity.exposures.base - INFO - category_id not set.
# 2020-02-28 16:50:49,117 - climada.entity.exposures.base - INFO - region_id not set.
# 2020-02-28 16:50:56,291 - climada.entity.exposures.base - INFO - Setting latitude and longitude attributes.
# 2020-02-28 16:51:01,171 - climada.util.coordinates - INFO - Setting geometry points.
# 2020-02-28 16:51:08,745 - climada.entity.exposures.base - INFO - tag metadata set to default value:  File:
#  Description:
# 2020-02-28 16:51:08,746 - climada.entity.exposures.base - INFO - ref_year metadata set to default value: 2018
# 2020-02-28 16:51:08,747 - climada.entity.exposures.base - INFO - meta metadata set to default value: None
# 2020-02-28 16:51:08,748 - climada.entity.exposures.base - INFO - centr_ not set.
# 2020-02-28 16:51:08,748 - climada.entity.exposures.base - INFO - deductible not set.
# 2020-02-28 16:51:08,748 - climada.entity.exposures.base - INFO - cover not set.
# 2020-02-28 16:51:08,749 - climada.entity.exposures.base - INFO - category_id not set.
# 2020-02-28 16:51:08,749 - climada.entity.exposures.base - INFO - region_id not set.
# 2020-02-28 16:51:16,049 - climada.entity.exposures.base - INFO - Setting latitude and longitude attributes.
# 2020-02-28 16:51:20,743 - climada.util.coordinates - INFO - Setting geometry points.
# 2020-02-28 16:51:27,955 - climada.entity.exposures.base - INFO - tag metadata set to default value:  File:
#  Description:
# 2020-02-28 16:51:27,956 - climada.entity.exposures.base - INFO - ref_year metadata set to default value: 2018
# 2020-02-28 16:51:27,956 - climada.entity.exposures.base - INFO - meta metadata set to default value: None
# 2020-02-28 16:51:27,957 - climada.entity.exposures.base - INFO - centr_ not set.
# 2020-02-28 16:51:27,957 - climada.entity.exposures.base - INFO - deductible not set.
# 2020-02-28 16:51:27,958 - climada.entity.exposures.base - INFO - cover not set.
# 2020-02-28 16:51:27,959 - climada.entity.exposures.base - INFO - category_id not set.
# 2020-02-28 16:51:27,959 - climada.entity.exposures.base - INFO - region_id not set.
# 2020-02-28 16:51:34,946 - climada.entity.exposures.base - INFO - Setting latitude and longitude attributes.
# 2020-02-28 16:51:39,539 - climada.util.coordinates - INFO - Setting geometry points.
# 2020-02-28 16:51:46,662 - climada.entity.exposures.base - INFO - tag metadata set to default value:  File:
#  Description:
# 2020-02-28 16:51:46,663 - climada.entity.exposures.base - INFO - ref_year metadata set to default value: 2018
# 2020-02-28 16:51:46,663 - climada.entity.exposures.base - INFO - meta metadata set to default value: None
# 2020-02-28 16:51:46,664 - climada.entity.exposures.base - INFO - centr_ not set.
# 2020-02-28 16:51:46,665 - climada.entity.exposures.base - INFO - deductible not set.
# 2020-02-28 16:51:46,665 - climada.entity.exposures.base - INFO - cover not set.
# 2020-02-28 16:51:46,666 - climada.entity.exposures.base - INFO - category_id not set.
# 2020-02-28 16:51:46,666 - climada.entity.exposures.base - INFO - region_id not set.
# 2020-02-28 16:51:53,697 - climada.entity.exposures.base - INFO - Setting latitude and longitude attributes.

# %%
exposures['inside low physical activity'].plot_hexbin(bins = 'log',pop_name=False,cmap='PuRd')
plt.savefig('../figures/map_exposures_ch_low.pdf',bbox_inches='tight')
# Out:
# /Users/zeliestalhanske/anaconda3/climada_python-1.3.1/climada/util/plot.py:318: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.tight_layout()
