# %%
import sys
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import palettable

sys.path.append('../../src/write_entities/')
sys.path.append('../../src/util/')

from define_exposures import call_exposures

# %%
exposures = call_exposures()
# Out:
# 2020-03-02 15:15:44,082 - climada.util.coordinates - INFO - Setting geometry points.
# 2020-03-02 15:15:51,874 - climada.entity.exposures.base - INFO - tag metadata set to default value:  File:
#  Description:
# 2020-03-02 15:15:51,874 - climada.entity.exposures.base - INFO - ref_year metadata set to default value: 2018
# 2020-03-02 15:15:51,875 - climada.entity.exposures.base - INFO - meta metadata set to default value: None
# 2020-03-02 15:15:51,878 - climada.entity.exposures.base - INFO - centr_ not set.
# 2020-03-02 15:15:51,881 - climada.entity.exposures.base - INFO - deductible not set.
# 2020-03-02 15:15:51,881 - climada.entity.exposures.base - INFO - cover not set.
# 2020-03-02 15:15:51,882 - climada.entity.exposures.base - INFO - category_id not set.
# 2020-03-02 15:15:51,882 - climada.entity.exposures.base - INFO - region_id not set.
# 2020-03-02 15:16:00,299 - climada.entity.exposures.base - INFO - Setting latitude and longitude attributes.
# ...

# %%
exposures['inside low physical activity'].plot_scatter(pop_name=False,cmap='PuRd')
plt.savefig('../figures/map_exposures_ch_low.pdf',bbox_inches='tight')

# %%
exposures['inside low physical activity'].plot_raster()
# Out:
# 2020-03-02 15:30:52,054 - climada.util.coordinates - INFO - Raster from resolution 1.0009430617685666e-08 to 1.0009430617685666e-08.
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-11-68a416752c70> in <module>
# ----> 1 exposures['inside low physical activity'].plot_raster()
#
# ~/anaconda3/climada_python-1.3.1/climada/entity/exposures/base.py in plot_raster(self, res, raster_res, save_tiff, raster_f, label, scheduler, axis, **kwargs)
#     380         else:
#     381             raster, meta = co.points_to_raster(self, ['value'], res, raster_res,
# --> 382                                                scheduler)
#     383             raster = raster.reshape((meta['height'], meta['width']))
#     384         # save tiff
#
# ~/anaconda3/climada_python-1.3.1/climada/util/coordinates.py in points_to_raster(points_df, val_names, res, raster_res, scheduler)
# ...
